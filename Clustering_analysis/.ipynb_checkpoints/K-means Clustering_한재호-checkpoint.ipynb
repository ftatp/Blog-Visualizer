# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Total_csv.csv',sep='\t')

# %%
# best feature 추출
best_df = df[['Question_count','First_ratio','Second_ratio','Tag_count','pos_ratio',
 'neg_ratio','subjectivity','polarity','senti_diffs_per_ref','Sticker_count','Text_len','Count_space_mistake',
   'effort_ratio','effort_img_ratio','Left','Center','Right','Justify',
   'img img img img img','img img img img text','img img img text img','img img text img img','img img text img text',
 'img text img img img','img text img img text','img text img text img','text img img img img','text img img img text',
 'text img img text img','text img text img img','text img text img text','Credibility']]

print ("before: ", best_df.shape)
best_df = best_df.dropna()
print ("after: ", best_df.shape)
# Out:
# before:  (16304, 32)
# after:  (16213, 32)

# %%
from sklearn.utils import shuffle
best_df = shuffle(best_df)

# %%
Credibility = best_df[best_df['Credibility']==1]
Non_credibility = best_df[best_df['Credibility']==0]

# %% [markdown]
# # Credibility data shuffle

# %%
from sklearn.utils import shuffle
Credibility = shuffle(Credibility)
Non_credibility = shuffle(Non_credibility)
print ("credible: ", Credibility.shape)
print ("non: ",Non_credibility.shape)

train_credibility = Credibility[:6000]
train_non_credibility = Non_credibility[:6000]
print ("credible: ", train_credibility.shape)
print ("non: ", train_non_credibility.shape)

test_cred = Credibility[6000:6289]
test_non_cred = Non_credibility[6000:6289]
print ("credible: ", test_cred.shape)
print ("non: ", test_non_cred.shape)

df_test_total = pd.concat([test_cred, test_non_cred], axis = 0)
print ("shape: ", df_test_total.shape)
df_test_total.sample(10)
# Out:
# credible:  (9924, 32)
# non:  (6289, 32)
# credible:  (6000, 32)
# non:  (6000, 32)
# credible:  (289, 32)
# non:  (289, 32)
# shape:  (578, 32)
#        Question_count  First_ratio  Second_ratio  Tag_count  pos_ratio  \
# 4441                3     0.005489           0.0          7   0.026515
# 2981                4     0.000867           0.0          0   0.032653
# 8767                1     0.000000           0.0          4   0.076271
# 1001                0     0.000000           0.0          1   0.000000
# 12298               1     0.002573           0.0          4   0.023346
# 11550               2     0.001303           0.0          5   0.069252
# 2931                0     0.000000           0.0          9   0.037815
# 6258                2     0.002904           0.0          5   0.010050
# 226                 0     0.000000           0.0          3   0.026144
# 4799                0     0.001934           0.0          0   0.094017
#
# ...

# %%
df_train_total = pd.concat([train_credibility, train_non_credibility])
print ("shape: ", df_train_total.shape)
df_train_total.sample(10)
# Out:
# shape:  (12000, 32)
#        Question_count  First_ratio  Second_ratio  Tag_count  pos_ratio  \
# 4125                0     0.000000           0.0          0   0.000000
# 3126                5     0.000000           0.0          0   0.036290
# 11408               9     0.001848           0.0          2   0.049505
# 7730                0     0.000000           0.0          6   0.040161
# 8443                0     0.000000           0.0          2   0.030769
# 2848                0     0.000688           0.0          5   0.033445
# 14949               2     0.000752           0.0          6   0.043605
# 8881                4     0.000000           0.0          2   0.051613
# 2803                0     0.000000           0.0          0   0.023810
# 11486               0     0.000000           0.0          3   0.000000
#
#        neg_ratio  subjectivity  polarity  senti_diffs_per_ref  Sticker_count  \
# 4125    0.071429      0.071429  1.000000            -0.071429            0.0
# ...

# %%
from sklearn.utils import shuffle
df_train_total = shuffle(df_train_total)
df_test_total = shuffle(df_test_total)
df_train_total = df_train_total.reset_index(drop=True)
df_test_total = df_test_total.reset_index(drop=True)
df_train_total.head(10)
# Out:
#    Question_count  First_ratio  Second_ratio  Tag_count  pos_ratio  neg_ratio  \
# 0               0     0.000000      0.000000          6   0.040161   0.040161
# 1               2     0.004769      0.000000         10   0.075540   0.035971
# 2               1     0.000000      0.000000          2   0.039604   0.049505
# 3               2     0.003704      0.000926         10   0.053140   0.028986
# 4               2     0.011200      0.000000         10   0.106529   0.024055
# 5               0     0.009412      0.000000          0   0.027304   0.044369
# 6               0     0.000000      0.000000          6   0.047393   0.037915
# 7               2     0.000000      0.000000          5   0.049724   0.016575
# 8               4     0.000000      0.000000          2   0.025030   0.061979
# 9               0     0.001292      0.000000          4   0.019737   0.013158
#
#    subjectivity  polarity  senti_diffs_per_ref  Sticker_count     ...       \
# ...

# %% [markdown]
# # x, y selection

# %%
x = df_train_total.drop(columns=['Credibility'])
y = df_train_total[['Credibility']]
x.head(10)
# Out:
#    Question_count  First_ratio  Second_ratio  Tag_count  pos_ratio  neg_ratio  \
# 0               0     0.000000      0.000000          6   0.040161   0.040161
# 1               2     0.004769      0.000000         10   0.075540   0.035971
# 2               1     0.000000      0.000000          2   0.039604   0.049505
# 3               2     0.003704      0.000926         10   0.053140   0.028986
# 4               2     0.011200      0.000000         10   0.106529   0.024055
# 5               0     0.009412      0.000000          0   0.027304   0.044369
# 6               0     0.000000      0.000000          6   0.047393   0.037915
# 7               2     0.000000      0.000000          5   0.049724   0.016575
# 8               4     0.000000      0.000000          2   0.025030   0.061979
# 9               0     0.001292      0.000000          4   0.019737   0.013158
#
#    subjectivity  polarity  senti_diffs_per_ref  Sticker_count  \
# ...

# %%
y.head(10)
# Out:
#    Credibility
# 0            0
# 1            1
# 2            0
# 3            0
# 4            0
# 5            1
# 6            0
# 7            0
# 8            1
# 9            0

# %% [markdown]
# # K-means Clustering

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

def k_means_clustering(data, num):
    scaler = StandardScaler()
    model = KMeans(init="k-means++", n_clusters=num, random_state=42)
    pipeline = make_pipeline(scaler, model)
    pipeline.fit(data)
    predict_class = pd.DataFrame(pipeline.predict(data))
    predict_class.columns = ['class']
    return predict_class

def create_cross_table(y, predict_class):
    cross_table = pd.crosstab(y['Credibility'], predict_class['class'])
    cross_table.loc['total'] = cross_table.select_dtypes(pd.np.number).sum()
    cross_table.iloc[0] = cross_table.iloc[0] / cross_table.iloc[2]
    cross_table.iloc[1] = cross_table.iloc[1] / cross_table.iloc[2]
    
    # over 60 detect
    list_class = []
    list_credible = []

    for i in range(2): # credible
        for j in range(len(cross_table.iloc[i])): # class
            if cross_table.iloc[i][j] >= 0.6:
                list_credible.append(i)
                list_class.append(j)

    over60_zip = list(zip(list_class, list_credible))
    over60_zip.sort(key = lambda x: x[0])
    print ("한 쪽이 60% 넘는 총 개수는 {0} 개".format(len(over60_zip)))
    for i in range(len(over60_zip)):
        print ("60%가 넘는 것은 class: {0}, credibility: {1} 일 때 입니다. ".format(over60_zip[i][0], over60_zip[i][1]))
    
    return cross_table

# %%
predict_feature_all_4 = k_means_clustering(x, 4)
ct4 = create_cross_table(y, predict_feature_all_4)
ct4
# Out:
# 한 쪽이 60% 넘는 총 개수는 2 개
# 60%가 넘는 것은 class: 0, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 2, credibility: 0 일 때 입니다.
# class                  0           1    2            3
# Credibility
# 0               0.286633     0.53347  1.0     0.508239
# 1               0.713367     0.46653  0.0     0.491761
# total        1399.000000  8291.00000  4.0  2306.000000

# %%
predict_feature_all_5 = k_means_clustering(x, 5)
ct5 = create_cross_table(y, predict_feature_all_5)
ct5
# Out:
# 한 쪽이 60% 넘는 총 개수는 4 개
# 60%가 넘는 것은 class: 0, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 1, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 2, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 4, credibility: 0 일 때 입니다.
# class                  0            1            2            3    4
# Credibility
# 0               0.112989     0.320755     0.629452     0.563231  1.0
# 1               0.887011     0.679245     0.370548     0.436769  0.0
# total        2071.000000  1166.000000  6879.000000  1882.000000  2.0

# %%
predict_feature_all_6 = k_means_clustering(x, 6)
ct6 = create_cross_table(y, predict_feature_all_6)
ct6
# Out:
# 한 쪽이 60% 넘는 총 개수는 5 개
# 60%가 넘는 것은 class: 0, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 1, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 2, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 4, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 5, credibility: 0 일 때 입니다.
# class                  0            1    2            3    4            5
# Credibility
# 0               0.319828     0.113153  1.0     0.561105  1.0     0.629592
# 1               0.680172     0.886847  0.0     0.438895  0.0     0.370408
# total        1160.000000  2068.000000  2.0  1882.000000  1.0  6887.000000

# %%
predict_feature_all_7 = k_means_clustering(x, 7)
ct7 = create_cross_table(y, predict_feature_all_7)
ct7
# Out:
# 한 쪽이 60% 넘는 총 개수는 5 개
# 60%가 넘는 것은 class: 1, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 3, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 4, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 5, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 6, credibility: 1 일 때 입니다.
# class                  0            1            2           3    4  \
# Credibility
# 0               0.445499     0.138107     0.572124    0.390278  1.0
# 1               0.554501     0.861893     0.427876    0.609722  0.0
# total        2633.000000  1564.000000  1643.000000  720.000000  2.0
#
# class                  5           6
# Credibility
# 0               0.674205    0.303595
# 1               0.325795    0.696405
# total        4687.000000  751.000000

# %%
predict_feature_all_8 = k_means_clustering(x, 8)
ct8 = create_cross_table(y, predict_feature_all_8)
ct8
# Out:
# 한 쪽이 60% 넘는 총 개수는 7 개
# 60%가 넘는 것은 class: 0, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 1, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 2, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 3, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 4, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 5, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 6, credibility: 0 일 때 입니다.
# class                  0           1    2    3           4            5  \
# Credibility
# 0               0.113797    0.302667  1.0  1.0    0.381955     0.603978
# 1               0.886203    0.697333  0.0  0.0    0.618045     0.396022
# total        1986.000000  750.000000  1.0  1.0  665.000000  1659.000000
#
# class                  6           7
# Credibility
# 0               0.621562    0.583333
# 1               0.378438    0.416667
# total        6326.000000  612.000000

# %%
predict_feature_all_9 = k_means_clustering(x, 9)
ct9 = create_cross_table(y, predict_feature_all_9)
ct9
# Out:
# 한 쪽이 60% 넘는 총 개수는 6 개
# 60%가 넘는 것은 class: 2, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 3, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 4, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 6, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 7, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 8, credibility: 0 일 때 입니다.
# class                  0            1            2            3           4  \
# Credibility
# 0               0.530565     0.569932     0.693769     0.033282    0.264507
# 1               0.469435     0.430068     0.306231     0.966718    0.735493
# total        3010.000000  1623.000000  3948.000000  1292.000000  741.000000
#
# class                 5           6    7    8
# Credibility
# 0              0.400875    0.318508  1.0  1.0
# 1              0.599125    0.681492  0.0  0.0
# total        686.000000  697.000000  2.0  1.0

# %%
predict_feature_all_10 = k_means_clustering(x, 10)
ct10 = create_cross_table(y, predict_feature_all_10)
ct10
# Out:
# 한 쪽이 60% 넘는 총 개수는 7 개
# 60%가 넘는 것은 class: 0, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 1, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 3, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 5, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 7, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 8, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 9, credibility: 0 일 때 입니다.
# class                 0            1            2    3           4  \
# Credibility
# 0              0.301205     0.682158     0.522903  1.0     0.59322
# 1              0.698795     0.317842     0.477097  0.0     0.40678
# total        747.000000  3206.000000  3624.000000  1.0  1475.00000
#
# class                  5          6           7    8    9
# Credibility
# 0               0.130869    0.58092    0.383792  1.0  1.0
# 1               0.869131    0.41908    0.616208  0.0  0.0
# total        1704.000000  587.00000  654.000000  1.0  1.0

# %%
predict_feature_all_11 = k_means_clustering(x, 11)
ct11 = create_cross_table(y, predict_feature_all_11)
ct11
# Out:
# 한 쪽이 60% 넘는 총 개수는 8 개
# 60%가 넘는 것은 class: 0, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 2, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 3, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 6, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 7, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 8, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 9, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 10, credibility: 0 일 때 입니다.
# class                0            1            2           3           4   \
# Credibility
# 0              0.263514     0.526934     0.033359     0.69088    0.581197
# 1              0.736486     0.473066     0.966641     0.30912    0.418803
# total        740.000000  2896.000000  1289.000000  3717.00000  585.000000
#
# class                 5    6           7           8    9    10
# Credibility
# 0               0.592186  1.0    0.391653    0.315407  1.0  1.0
# 1               0.407814  0.0    0.608347    0.684593  0.0  0.0
# ...

# %%
predict_feature_all_12 = k_means_clustering(x, 12)
ct12 = create_cross_table(y, predict_feature_all_12)
ct12
# Out:
# 한 쪽이 60% 넘는 총 개수는 9 개
# 60%가 넘는 것은 class: 1, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 2, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 3, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 5, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 6, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 7, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 9, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 10, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 11, credibility: 0 일 때 입니다.
# class                 0           1           2    3           4   \
# Credibility
# 0               0.554054    0.265223    0.311143  1.0     0.59375
# 1               0.445946    0.734777    0.688857  0.0     0.40625
# total        3552.000000  739.000000  691.000000  1.0  1472.00000
#
# class                 5    6            7           8          9          10  \
# Credibility
# 0               0.034188  1.0     0.694782    0.581197    0.39478   0.090909
# 1               0.965812  0.0     0.305218    0.418803    0.60522   0.909091
# ...

# %%
predict_feature_all_13 = k_means_clustering(x, 13)
ct13 = create_cross_table(y, predict_feature_all_13)
ct13 # remove 3,7,9,10 / 13개
# Out:
# 한 쪽이 60% 넘는 총 개수는 10 개
# 60%가 넘는 것은 class: 0, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 1, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 2, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 3, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 4, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 5, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 6, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 7, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 9, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 10, credibility: 1 일 때 입니다.
# class                0            1           2    3           4   \
# Credibility
# 0              0.133333     0.033646    0.317251  1.0    0.393204
# 1              0.866667     0.966354    0.682749  0.0    0.606796
# total        195.000000  1278.000000  684.000000  1.0  618.000000
#
# class                 5           6    7           8    9     10           11  \
# Credibility
# 0               0.700764    0.269337  1.0    0.580479  1.0   0.0     0.536898
# ...

# %%
predict_feature_all_14 = k_means_clustering(x, 14)
ct14 = create_cross_table(y, predict_feature_all_14)
ct14
# Out:
# 한 쪽이 60% 넘는 총 개수는 9 개
# 60%가 넘는 것은 class: 2, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 3, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 4, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 5, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 8, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 9, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 11, credibility: 0 일 때 입니다.
# 60%가 넘는 것은 class: 12, credibility: 1 일 때 입니다.
# 60%가 넘는 것은 class: 13, credibility: 0 일 때 입니다.
# class                0            1    2    3           4            5   \
# Credibility
# 0              0.580205     0.555085  1.0  1.0    0.316401     0.033254
# 1              0.419795     0.444915  0.0  0.0    0.683599     0.966746
# total        586.000000  3304.000000  1.0  1.0  689.000000  1263.000000
#
# class                6     7           8    9            10   11          12  \
# Credibility
# 0              0.560065   0.5    0.390675  1.0     0.592998  1.0    0.255587
# ...

# %% [markdown]
# # ct13 선택, 아직 편입은 미개발

# %%
df_clustering13_all = pd.concat([x, predict_feature_all_13], axis = 1)
df_clustering13_all.sample(5)
# Out:
#        Question_count  First_ratio  Second_ratio  Tag_count  pos_ratio  \
# 4070                3     0.000000      0.000000          5   0.027778
# 10333               5     0.002725      0.000000          1   0.026316
# 2758                0     0.000000      0.000000          9   0.017751
# 10024               0     0.000000      0.001311          9   0.031447
# 1249                2     0.004822      0.000964          7   0.049020
#
#        neg_ratio  subjectivity  polarity  senti_diffs_per_ref  Sticker_count  \
# 4070    0.037037      0.064815  0.142857            -0.009259            2.0
# 10333   0.046784      0.073099  0.280000            -0.020468            0.0
# 2758    0.047337      0.065089  0.454545            -0.029586            0.0
# 10024   0.037736      0.069182  0.090909            -0.006289            0.0
# 1249    0.044118      0.093137 -0.052632             0.004902            1.0
#
#        ...    img img text img text  img text img img img  \
# ...

# %%
# class 3,7,9,10 제거
print ("shape: ", df_clustering13_all.shape)
df_clustering13_remove4 = df_clustering13_all[df_clustering13_all['class'] != 3]
df_clustering13_remove4 = df_clustering13_remove4[df_clustering13_remove4['class'] != 7]
df_clustering13_remove4 = df_clustering13_remove4[df_clustering13_remove4['class'] != 9]
df_clustering13_remove4 = df_clustering13_remove4[df_clustering13_remove4['class'] != 10]
print ("shape: ", df_clustering13_remove4.shape)
df_clustering13_remove4.sample(10)
# Out:
# shape:  (12000, 32)
# shape:  (11987, 32)
#        Question_count  First_ratio  Second_ratio  Tag_count  pos_ratio  \
# 4495                1     0.001889           0.0          9   0.060811
# 2504                1     0.000000           0.0          9   0.028428
# 5226                0     0.001251           0.0         10   0.030369
# 10286               0     0.005319           0.0          3   0.047619
# 4977                0     0.003165           0.0          7   0.000000
# 10639               1     0.000000           0.0          9   0.056940
# 10488               1     0.001963           0.0          9   0.026316
# 2044                2     0.000000           0.0          5   0.028249
# 3607                0     0.004405           0.0          3   0.032967
# 455                 0     0.000000           0.0          5   0.015707
#
#        neg_ratio  subjectivity  polarity  senti_diffs_per_ref  Sticker_count  \
# ...

# %%
# ct8
df_clustering8_all = pd.concat([x, predict_feature_all_8], axis = 1)
df_clustering8_all.sample(5)
# Out:
#        Question_count  First_ratio  Second_ratio  Tag_count     pos_ratio  \
# 3416                0          0.0           0.0          9  1.000000e-09
# 6747                2          0.0           0.0          0  3.015075e-02
# 1631                0          0.0           0.0          5  2.371542e-02
# 10259               0          0.0           0.0          1  2.782609e-02
# 1937                1          0.0           0.0          3  4.687500e-02
#
#           neg_ratio  subjectivity      polarity  senti_diffs_per_ref  \
# 3416   1.000000e-09  1.000000e-09  1.000000e-09         1.000000e-09
# 6747   3.517588e-02  6.532663e-02  7.692308e-02        -5.025126e-03
# 1631   1.976285e-02  4.347826e-02 -9.090909e-02         3.952569e-03
# 10259  2.608696e-02  5.391304e-02 -3.225806e-02         1.739130e-03
# 1937   1.041667e-02  5.729167e-02 -6.363636e-01         3.645833e-02
#
#        Sticker_count  ...    img img text img text  img text img img img  \
# ...

# %%
# class 2,3 제거
print ("shape: ", df_clustering8_all.shape)
df_clustering8_remove2 = df_clustering8_all[df_clustering8_all['class'] != 2]
df_clustering8_remove2 = df_clustering8_remove2[df_clustering8_remove2['class'] != 3]
print ("shape: ", df_clustering8_remove2.shape)
df_clustering8_remove2.sample(10)
# Out:
# shape:  (12000, 32)
# shape:  (11998, 32)
#       Question_count  First_ratio  Second_ratio  Tag_count     pos_ratio  \
# 2432               5     0.002024           0.0          3  4.166667e-02
# 4506               0     0.001399           0.0          0  2.362205e-02
# 3747               0     0.000000           0.0          7  5.660377e-02
# 9864               2     0.000518           0.0          8  4.422254e-02
# 6048               0     0.006757           0.0          7  9.452736e-02
# 8596               0     0.000902           0.0          0  4.184100e-02
# 4768               1     0.003130           0.0          0  1.739130e-02
# 7925               1     0.000881           0.0          2  3.404255e-02
# 6816               0     0.000000           0.0          3  1.000000e-09
# 7268               0     0.000811           0.0         10  4.090909e-02
#
#          neg_ratio  subjectivity      polarity  senti_diffs_per_ref  \
# ...

# %% [markdown]
# # structure, sentiment, other

# %%
# structure data
structure_features = ['img img img img img', 'img img img img text', 'img img img text img',
                      'img img text img img', 'img img text img text', 'img text img img img',
                      'img text img img text', 'img text img text img', 'text img img img img',
                      'text img img img text', 'text img img text img', 'text img text img img', 
                      'text img text img text', 'class'] # total 13, class 제외

df_structure = df_clustering8_remove2[structure_features]
print ("shape: ", df_structure.shape)
df_structure.sample(10)
# Out:
# shape:  (11987, 14)
#        img img img img img  img img img img text  img img img text img  \
# 1458                   0.0                   0.0                   0.0
# 536                    0.0                   0.0                   0.0
# 8545                   0.0                   0.0                   0.0
# 8550                   0.0                   0.0                   0.0
# 7993                   0.0                   0.0                   0.0
# 2192                   0.0                   0.0                   0.0
# 3140                   0.0                   0.0                   0.0
# 3261                   0.0                   0.0                   0.0
# 9786                   0.0                   0.0                   0.0
# 11820                  0.0                   0.0                   0.0
#
#        img img text img img  img img text img text  img text img img img  \
# 1458                    0.0               0.000000              0.000000
# ...

# %%
# save strucuture data
# df_structure.to_csv("data/df_structure8_sampling.csv", header = True, index = False)

# %%
# sentiment data
sentiment_features = ['pos_ratio', 'neg_ratio', 'subjectivity', 'polarity', 'senti_diffs_per_ref', 'class']
df_sentiment = df_clustering8_remove2[sentiment_features]
print ("shape: ", df_sentiment.shape)
df_sentiment.sample(10)
# Out:
# shape:  (11998, 6)
#        pos_ratio  neg_ratio  subjectivity      polarity  senti_diffs_per_ref  \
# 7822    0.036082   0.030928      0.067010 -7.692308e-02             0.005155
# 10687   0.035019   0.023346      0.058366 -2.000000e-01             0.011673
# 77      0.032641   0.059347      0.091988  2.903226e-01            -0.026706
# 4207    0.025253   0.040404      0.065657  2.307692e-01            -0.015152
# 7583    0.042773   0.069322      0.112094  2.368421e-01            -0.026549
# 2118    0.008130   0.032520      0.040650  6.000000e-01            -0.024390
# 9868    0.037383   0.037383      0.074766  0.000000e+00             0.000000
# 9666    0.037037   0.064815      0.101852  2.727273e-01            -0.027778
# 11729   0.000000   0.000000      0.000000  1.000000e-09             0.000000
# 10111   0.077640   0.027950      0.105590 -4.705882e-01             0.049689
#
#        class
# 7822       6
# 10687      6
# 77         0
# 4207       7
# 7583       5
# 2118       6
# ...

# %%
# save sentiment data
df_sentiment.to_csv("data/df_sentiment8_sampling.csv", header = True, index = False)

# %%
# others
others_features = ['Tag_count', 'First_ratio', 'Second_ratio', 'Sticker_count', 'Text_len', 'effort_img_ratio',
                   'Count_space_mistake', 'effort_ratio', 'Left', 'Center', 'Right', 'Justify', 'Question_count', 'class']

df_others = df_clustering8_remove2[others_features]
print ("shape: ", df_others.shape)
df_others.sample(10)
# Out:
# shape:  (11998, 14)
#        Tag_count  First_ratio  Second_ratio  Sticker_count  Text_len  \
# 4670           2     0.000000      0.001689            0.0     592.0
# 6065          10     0.000785      0.000000            0.0    1274.0
# 4030           0     0.002436      0.000000            0.0    1642.0
# 6224           8     0.001275      0.000000            0.0    4705.0
# 6263           0     0.000000      0.000000            0.0     717.0
# 11450         10     0.000000      0.000000            0.0     893.0
# 9818           0     0.000000      0.000000            0.0     556.0
# 11004          4     0.002191      0.000000            0.0    2282.0
# 7823           0     0.000000      0.000000            0.0    1438.0
# 6262          10     0.002519      0.000840            5.0    1191.0
#
#        effort_img_ratio  Count_space_mistake  effort_ratio  Left  Center  \
# 4670           0.382571                  7.0      0.773912   0.0     0.0
# ...

# %%
# save others data
df_others.to_csv("data/df_others8_sampling.csv", header = True, index = False)

# %% [markdown]
# # end 10/29, 01:00

# %%
features10_temp = features10.copy()
features10_temp.append('class')
features10_temp
# Out:
# ['Left',
#  'neg_ratio',
#  'Justify',
#  'text img text img text',
#  'Count_space_mistake',
#  'img text img text img',
#  'effort_ratio',
#  'Text_len',
#  'effort_img_ratio',
#  'Center',
#  'class']

# %%
df_clustering_all_select10 = df_clustering_all[features10_temp]
print ("shape: ", df_clustering_all_select10.shape)
df_clustering_all_select10.sample(5)
# Out:
# shape:  (16213, 15)
#        Left  neg_ratio  Justify  text img text img text  Count_space_mistake  \
# 12997   0.0   0.057072      0.0                0.000000                 48.0
# 12663   0.0   0.016667      3.0                0.497686                 20.0
# 7193    0.0   0.025641      0.0                0.147281                 36.0
# 12238   0.0   0.038462      0.0                0.643737                 64.0
# 9862   11.0   0.050239     26.0                0.000000                 23.0
#
#        img text img text img  effort_ratio  Text_len  effort_img_ratio  \
# 12997               0.000000      2.397896    3522.0          1.592440
# 12663               0.596729      0.624454     844.0          1.131740
# 7193                0.147159      0.400008     617.0          0.644624
# 12238               0.643204      0.945877    1306.0          0.885958
# 9862                0.000000      1.083553    1762.0          1.497613
#
#        Center  class  class  class  class  class
# ...

# %%
# save data
# df_clustering_all.to_csv('data/clustering_all.csv', header=True, index=False)
# df_clustering_all_select10.to_csv('data/clustering_all_select10.csv', header=True, index=False)

# %% [markdown]
# # radviz

# %%
# 10개 변수로 clustering
features10 = ['Left', 'neg_ratio', 'Justify', 'text img text img text', 'Count_space_mistake',
              'img text img text img', 'effort_ratio', 'Text_len', 'effort_img_ratio', 'Center']

df_features10_x = x[features10]
print (df_features10_x.shape)
df_features10_x.head(10)
# Out:
# (16213, 10)
#    Left     neg_ratio  Justify  text img text img text  Count_space_mistake  \
# 0   0.0  5.329154e-02     11.0                0.317769                 32.0
# 1   0.0  1.020408e-01      0.0                0.230560                 11.0
# 2   1.0  2.072539e-02      0.0                0.700485                 57.0
# 3  27.0  5.490196e-02     12.0                0.401655                 59.0
# 4   0.0  4.697987e-02      0.0                0.614705                 28.0
# 5  15.0  2.090592e-02      6.0                0.324336                 39.0
# 6   0.0  5.394191e-02     12.0                0.374921                 44.0
# 7   0.0  1.619433e-02      6.0                0.184331                 10.0
# 8   0.0  1.000000e-09     24.0                0.000000                  0.0
# 9   0.0  3.108808e-02      0.0                0.722928                 49.0
#
#    img text img text img  effort_ratio    Text_len  effort_img_ratio  Center
# ...

# %%
# 10개 변수로 clustering
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scaler = StandardScaler()
feature10_model = KMeans(n_clusters=5)
pipeline = make_pipeline(scaler,feature10_model)
pipeline.fit(df_features10_x)
predict_feature10 = pd.DataFrame(pipeline.predict(df_features10_x))

# %%
predict_feature10.columns = ['class']
predict_feature10
# Out:
#        class
# 0          2
# 1          2
# 2          3
# 3          2
# 4          3
# 5          3
# 6          2
# 7          2
# 8          3
# 9          3
# 10         3
# 11         2
# 12         2
# 13         2
# 14         2
# 15         2
# 16         2
# 17         0
# 18         3
# 19         2
# 20         2
# 21         2
# 22         3
# 23         2
# 24         2
# 25         2
# 26         2
# 27         2
# 28         2
# 29         2
# ...      ...
# 16183      2
# 16184      0
# 16185      2
# 16186      2
# 16187      3
# 16188      2
# 16189      3
# 16190      2
# 16191      3
# 16192      2
# 16193      3
# 16194      3
# 16195      2
# 16196      2
# 16197      3
# 16198      2
# 16199      2
# 16200      2
# 16201      2
# 16202      3
# 16203      2
# 16204      2
# 16205      3
# 16206      2
# 16207      2
# 16208      2
# 16209      2
# 16210      2
# 16211      3
# 16212      2
#
# [16213 rows x 1 columns]

# %%
ct10 = pd.crosstab(y['Credibility'], predict_feature10['class'])
ct10.loc['total'] = ct10.select_dtypes(pd.np.number).sum()
ct10.iloc [0] = ct10.iloc[0] / ct10.iloc[2]
ct10.iloc [1] = ct10.iloc[1] / ct10.iloc[2]
ct10
# Out:
# class                 0    1             2            3    4
# Credibility
# 0              0.394834  0.0      0.387016     0.389037  1.0
# 1              0.605166  1.0      0.612984     0.610963  0.0
# total        542.000000  3.0  10413.000000  5254.000000  1.0

# %%
cluster_data10 = pd.concat([x,predict_feature10], axis=1)
print ("shape: ", cluster_data10.shape)
cluster_data10
# Out:
# shape:  (16213, 32)
#        Question_count  First_ratio  Second_ratio  Tag_count     pos_ratio  \
# 0                   1     0.000192      0.000000          0  3.498542e-02
# 1                   0     0.000537      0.000000          6  3.432494e-02
# 2                   2     0.009901      0.000000          9  2.564103e-02
# 3                   3     0.000943      0.003774         10  5.579399e-02
# 4                   0     0.000000      0.000000          0  4.945055e-02
# 5                   0     0.000763      0.000000          7  4.006678e-02
# 6                   5     0.002273      0.000000          2  2.631579e-02
# 7                   1     0.000000      0.000000          8  8.108108e-02
# 8                   0     0.000000      0.000000          7  1.818182e-02
# 9                   0     0.000000      0.000000          4  0.000000e+00
# 10                  0     0.000000      0.000000          1  0.000000e+00
# ...

# %%
# save data

# %% [markdown]
# # end

# %%
predict.columns = ['predict']

# %%
y = y.reset_index(drop=True)

# %%
ct = pd.crosstab(y['Credibility'],predict['predict'])

# %%
ct.loc['total'] = ct.select_dtypes(pd.np.number).sum()

# %%
ct

# %%
ct.iloc [0] = ct.iloc[0] / ct.iloc[2]
ct.iloc [1] = ct.iloc[1] / ct.iloc[2]
ct

# %%
ks = range(1,30)

inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(x)
    inertias.append(model.inertia_)

# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %% [markdown]
# # 각 Group 비교하기

# %% [markdown]
# ## Standard scaler

# %%
col_name = x.columns.tolist()
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
scaled_x = scaler.transform(x)
scaled_x_df = pd.DataFrame(scaled_x)
scaled_x_df.columns = col_name
scaled_x_df

# %%
scaled_x_structure = scaled_x_df[['img img img img img',
 'img img img img text',
 'img img img text img',
 'img img text img img',
 'img img text img text',
 'img text img img img',
 'img text img img text',
 'img text img text img',
 'text img img img img',
 'text img img img text',
 'text img img text img',
 'text img text img img',
 'text img text img text']]

# %%
df_analysis = pd.concat([scaled_x_structure,predict,y],axis=1)

# %%
df_0 = df_analysis[df_analysis['predict']==0]
df_1 = df_analysis[df_analysis['predict']==1]
df_2 = df_analysis[df_analysis['predict']==2]
df_3 = df_analysis[df_analysis['predict']==3]
df_4 = df_analysis[df_analysis['predict']==4]
df_0

# %%
df_0 = df_0.drop(columns=['Credibility','predict'])
df_1 = df_1.drop(columns=['Credibility','predict'])
df_2 = df_2.drop(columns=['Credibility','predict'])
df_3 = df_3.drop(columns=['Credibility','predict'])
df_4 = df_4.drop(columns=['Credibility','predict'])
df_0

# %% [markdown]
# # Python Radar chart - Structure

# %%
import matplotlib.pyplot as plt
from math import pi

# %%
df_0_mean = df_0.describe().iloc[1]
df_1_mean = df_1.describe().iloc[1]
df_2_mean = df_2.describe().iloc[1]
df_3_mean = df_3.describe().iloc[1]
df_0_mean

# %%
df_0 = pd.DataFrame(df_0_mean).T
df_1 = pd.DataFrame(df_1_mean).T
df_2 = pd.DataFrame(df_2_mean).T
df_3 = pd.DataFrame(df_3_mean).T
df_0

# %%
Total_df = pd.concat([df_0,df_1,df_2,df_3])
Total_df

# %%
predict_col = pd.DataFrame({'predict':[1,2,3,4]})
Total_df['predict'] = [1,2,3,4]
Total_df

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# ------- PART 1: Create background
 
# number of variable
categories=list(Total_df)[:-1]
print (categories)
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
print (angles)
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([-3,0,3], ["-3","0","3"], color="grey", size=7)
plt.ylim(-3,3)
 
 
# # ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values = Total_df.iloc[0].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group A")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values= Total_df.iloc[1].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values= Total_df.iloc[2].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'c', alpha=0.1)

# Ind4
values= Total_df.iloc[3].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'm', alpha=0.1)

# %% [markdown]
# # Python Radar chart - Sentiment

# %%
scaled_x_sentiment = scaled_x_df[['pos_ratio',
 'neg_ratio',
 'subjectivity',
 'polarity',
 'senti_diffs_per_ref',]]

# %%
df_analysis = pd.concat([scaled_x_sentiment,predict,y],axis=1)

# %%
df_0 = df_analysis[df_analysis['predict']==0]
df_1 = df_analysis[df_analysis['predict']==1]
df_2 = df_analysis[df_analysis['predict']==2]
df_3 = df_analysis[df_analysis['predict']==3]
df_4 = df_analysis[df_analysis['predict']==4]

# %%
df_0 = df_0.drop(columns=['Credibility','predict'])
df_1 = df_1.drop(columns=['Credibility','predict'])
df_2 = df_2.drop(columns=['Credibility','predict'])
df_3 = df_3.drop(columns=['Credibility','predict'])
df_4 = df_4.drop(columns=['Credibility','predict'])

# %%
import matplotlib.pyplot as plt
from math import pi

# %%
df_0_mean = df_0.describe().iloc[1]
df_1_mean = df_1.describe().iloc[1]
df_2_mean = df_2.describe().iloc[1]
df_3_mean = df_3.describe().iloc[1]

# %%
df_0 = pd.DataFrame(df_0_mean).T
df_1 = pd.DataFrame(df_1_mean).T
df_2 = pd.DataFrame(df_2_mean).T
df_3 = pd.DataFrame(df_3_mean).T

# %%
Total_df = pd.concat([df_0,df_1,df_2,df_3])

# %%
predict_col = pd.DataFrame({'predict':[1,2,3,4]})
Total_df['predict'] = [1,2,3,4]

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# ------- PART 1: Create background
 
# number of variable
categories=list(Total_df)[:-1]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([-0.2,0,0.2], ["-0.1","0","0.1"], color="grey", size=7)
plt.ylim(-0.2,0.2)
 
 
# # ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values = Total_df.iloc[0].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group A")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values= Total_df.iloc[1].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values= Total_df.iloc[2].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'c', alpha=0.1)

# Ind4
values= Total_df.iloc[3].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'm', alpha=0.1)

# %% [markdown]
# # Python Radar chart - Others

# %%
scaled_x_others = scaled_x_df[['FR_url',
 'Question_count',
 'First_ratio',
 'Second_ratio',
 'Tag_count',
'Sticker_count',
 'Text_len',
 'Count_space_mistake',
 'effort_ratio',
 'effort_img_ratio',
 'Left',
 'Center',
 'Right',
 'Justify']]

# %%
df_analysis = pd.concat([scaled_x_others,predict,y],axis=1)

# %%
df_0 = df_analysis[df_analysis['predict']==0]
df_1 = df_analysis[df_analysis['predict']==1]
df_2 = df_analysis[df_analysis['predict']==2]
df_3 = df_analysis[df_analysis['predict']==3]
df_4 = df_analysis[df_analysis['predict']==4]

# %%
df_0 = df_0.drop(columns=['Credibility','predict'])
df_1 = df_1.drop(columns=['Credibility','predict'])
df_2 = df_2.drop(columns=['Credibility','predict'])
df_3 = df_3.drop(columns=['Credibility','predict'])
df_4 = df_4.drop(columns=['Credibility','predict'])

# %%
import matplotlib.pyplot as plt
from math import pi

# %%
df_0_mean = df_0.describe().iloc[1]
df_1_mean = df_1.describe().iloc[1]
df_2_mean = df_2.describe().iloc[1]
df_3_mean = df_3.describe().iloc[1]

# %%
df_0 = pd.DataFrame(df_0_mean).T
df_1 = pd.DataFrame(df_1_mean).T
df_2 = pd.DataFrame(df_2_mean).T
df_3 = pd.DataFrame(df_3_mean).T

# %%
Total_df = pd.concat([df_0,df_1,df_2,df_3])

# %%
predict_col = pd.DataFrame({'predict':[1,2,3,4]})
Total_df['predict'] = [1,2,3,4]

# %%
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# ------- PART 1: Create background
 
# number of variable
categories=list(Total_df)[:-1]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([-0.5,0,5], ["-0.5","0","0.5"], color="grey", size=7)
plt.ylim(-0.5,0.5)
 
 
# # ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values = Total_df.iloc[0].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group A")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values= Total_df.iloc[1].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values= Total_df.iloc[2].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'c', alpha=0.1)

# Ind4
values= Total_df.iloc[3].drop('predict').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="group B")
ax.fill(angles, values, 'm', alpha=0.1)
